# %%
import numpy as np


def game_core_v2(r1, r2, number):
    t = range(r1, r2)  # создали список с диапазоном нижнего и верхнего порога
    count = 0

    while count < 1000:
        middle_num = len(t) // 2
        count += 1  # плюсуем попытку
        predict = t[middle_num]
        if number == predict + 1:
            break  # проверка крайних значений на равенство
        elif number == predict - 1:
            break  # проверка крайних значений на равенство
        if number == predict or number == len(t) or number == t[0]:
            break  # выход из цикла,если угадали или угадываемое число равно крайним значениям длины списка
        elif number > predict:
            print(f"Угадываемое число больше {predict} ")
            t = range(predict, predict + middle_num)
        elif number < predict:
            print(f"Угадываемое число меньше {predict} ")
            t = range(predict - middle_num, predict)

    print(f"Вы угадали число {number} за {count} попыток.")
    return count


def score_game(game_core_v2):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    r1 = 1 # нижний порог списка
    r2 = 101  # верхний порог списка
    random_array = np.random.randint(r1, r2, 1000)
    for number in random_array:
        count_ls.append(game_core_v2(r1, r2, number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return score

# %%
score_game(game_core_v2)
# Out:
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 44 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 47 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 15 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 73 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 64 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 90 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число больше 7
# Вы угадали число 9 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 45 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 17 за 5 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 57 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 36 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 97 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 39 за 3 попыток.
# Угадываемое число меньше 51
# Вы угадали число 27 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 21 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 21 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 65 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 87 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 30 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 73 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 39 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 73 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число меньше 51
# Вы угадали число 25 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 29 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 17 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 43 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 3 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 93 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 16 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 43 за 4 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 46 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 45 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 71 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 15 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 81 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 33 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 47 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 63 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 14 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 57 за 4 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 47 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 44 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 53 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 27 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число больше 7
# Вы угадали число 11 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 57 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 22 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 30 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число больше 51
# Вы угадали число 75 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 97 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 32 за 4 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число меньше 51
# Вы угадали число 27 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 90 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 29 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 60 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 8 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 14 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 41 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 54 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 83 за 4 попыток.
# Вы угадали число 1 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 72 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 78 за 5 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 31 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 94 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 94 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 6 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 79 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 4 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 43 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 12 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 4 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 87 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 59 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 84 за 5 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 71 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 15 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 84 за 5 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число больше 51
# Вы угадали число 77 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 96 за 5 попыток.
# Вы угадали число 100 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 21 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 89 за 3 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 19 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 6 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 62 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 41 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 81 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 53 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 89 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 64 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 6 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 45 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 95 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 93 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 31 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 59 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 6 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 64 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 48 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 97 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 89 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 60 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 55 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Вы угадали число 50 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 22 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 8 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 21 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 72 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 16 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 64 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 86 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 78 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 3 за 5 попыток.
# Вы угадали число 1 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 12 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 46 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 63 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 86 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 80 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 36 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 96 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 69 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 4 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 17 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Вы угадали число 52 за 1 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 36 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 81 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 72 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 62 за 3 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число больше 51
# Вы угадали число 75 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 29 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 63 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 3 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 15 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 88 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 45 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 44 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 46 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 42 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 95 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 82 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 63 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 72 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 35 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 71 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 96 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 71 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 82 за 4 попыток.
# Вы угадали число 52 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 71 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 17 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 35 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Вы угадали число 50 за 1 попыток.
# Угадываемое число больше 51
# Вы угадали число 77 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 21 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 60 за 5 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 95 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число больше 7
# Вы угадали число 10 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 36 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 5 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 90 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 94 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 78 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 84 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 31 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 54 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 53 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 60 за 5 попыток.
# Угадываемое число больше 51
# Вы угадали число 75 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 15 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 81 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 73 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 83 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Вы угадали число 75 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 88 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 83 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 32 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 82 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 3 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 79 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 38 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 12 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 63 за 3 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число меньше 51
# Вы угадали число 27 за 2 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 14 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 69 за 4 попыток.
# Вы угадали число 51 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 82 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 54 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 87 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 41 за 5 попыток.
# Вы угадали число 100 за 1 попыток.
# Вы угадали число 50 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 29 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 7 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 30 за 5 попыток.
# Вы угадали число 100 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 85 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 45 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 32 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 33 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 43 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 47 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 38 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 22 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 65 за 5 попыток.
# Вы угадали число 100 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 48 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 38 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 28 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 17 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 14 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 22 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 48 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 71 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 8 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 57 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 60 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 31 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 41 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 6 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 30 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 89 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 59 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 73 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число меньше 51
# Вы угадали число 25 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# ...
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 6 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 14 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 4 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 83 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 64 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 62 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 47 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число больше 7
# Вы угадали число 11 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 81 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 53 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 85 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 90 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 25 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 93 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 83 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 19 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 31 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 5 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 55 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 86 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 59 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 17 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 56 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 16 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число меньше 57
# Вы угадали число 54 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Угадываемое число больше 72
# Вы угадали число 74 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 67 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 5 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число больше 7
# Вы угадали число 9 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 63 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 97 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 44 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 68 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 69 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 62 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 59 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 62 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 97 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 30 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 88 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 8 за 4 попыток.
# Вы угадали число 100 за 1 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 41 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Вы угадали число 3 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 15 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 69 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 18 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 7 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Угадываемое число больше 47
# Вы угадали число 49 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Вы угадали число 37 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 35 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Вы угадали число 64 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 41 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 96 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 7 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 90 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 26 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Вы угадали число 81 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 40 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Вы угадали число 43 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 91 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 87 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Вы угадали число 88 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 90 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 23 за 5 попыток.
# Вы угадали число 50 за 1 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Угадываемое число больше 72
# Вы угадали число 74 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число меньше 32
# Вы угадали число 30 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 96 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Вы угадали число 8 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 12 за 3 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Вы угадали число 13 за 3 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число больше 7
# Вы угадали число 10 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 46 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 96 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Угадываемое число больше 22
# Вы угадали число 24 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Вы угадали число 20 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Вы угадали число 31 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Вы угадали число 98 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Вы угадали число 58 за 4 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число меньше 69
# Вы угадали число 65 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число больше 19
# Вы угадали число 22 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Угадываемое число больше 72
# Вы угадали число 74 за 6 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 46 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число меньше 13
# Угадываемое число меньше 7
# Угадываемое число меньше 4
# Вы угадали число 2 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 93 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 70 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 85 за 5 попыток.
# Угадываемое число больше 51
# Вы угадали число 76 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Вы угадали число 69 за 4 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число меньше 94
# Вы угадали число 92 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число меньше 38
# Угадываемое число больше 32
# Вы угадали число 34 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Угадываемое число больше 94
# Угадываемое число больше 97
# Вы угадали число 99 за 6 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число меньше 82
# Вы угадали число 78 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число больше 63
# Угадываемое число больше 69
# Вы угадали число 72 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число меньше 44
# Вы угадали число 42 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число меньше 88
# Угадываемое число больше 82
# Вы угадали число 84 за 5 попыток.
# Угадываемое число меньше 51
# Вы угадали число 27 за 2 попыток.
# Угадываемое число больше 51
# Угадываемое число меньше 76
# Угадываемое число меньше 63
# Угадываемое число больше 57
# Вы угадали число 61 за 5 попыток.
# Угадываемое число меньше 51
# Угадываемое число больше 26
# Угадываемое число больше 38
# Угадываемое число больше 44
# Вы угадали число 46 за 5 попыток.
# Угадываемое число больше 51
# Угадываемое число больше 76
# Угадываемое число больше 88
# Вы угадали число 95 за 4 попыток.
# Угадываемое число меньше 51
# Угадываемое число меньше 26
# Угадываемое число больше 13
# Угадываемое число меньше 19
# Вы угадали число 16 за 5 попыток.
# Ваш алгоритм угадывает число в среднем за 4 попыток
# 4
